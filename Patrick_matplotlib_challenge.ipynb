# %% [markdown]
# The 'Custom hillshading in a 3D surface plot' draws my attention, typically I use Matlab to create 3D visualizaitons of geographic data (e.g. detd, shp, etc) when a GIS environment is unavaliable. Over the past few years my primary research interest shifted to drone photogrammetry, I am quite curious whether this visualization could provide a faster solution in displaying small portions of point cloud data.  I think I'll give it a try.

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
ls
# Out:
# Feb5class.ipynb                       chessbuds_messages.json
# PatrickZhao_SystemsCheck.ipynb.ipynb  commute.csv
# Patrick_Pandas_challenge.ipynb        feb5demo.ipynb
# Patrick_matplotlib_challenge.ipynb    feb5p1.ipynb
# Patrick_tidy_data.ipynb               new.csv
# Project - Participation.ipynb         subset_cces_example_data.csv
# Spotify_Montero_data.json             untitled folder/
# Untitled.ipynb                        wk4.ipynb
# cces_example_data.csv                 wk6demo.ipynb

# %%
demo = pd.read_csv('cces_example_data.csv')

# %%
demo.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %%
fig1, ax1 = plt.subplots(figsize=(5, 2), layout='constrained')
ax1.set_xlabel('Age Histogram')
ax1.set_ylabel('Political Identity')
ax1.set_title("The Empty Figure")

plt.show()

# %%
agm = demo.groupby('age')['Evaluation'].mean().reset_index()

fig2, ax2 = plt.subplots(figsize = (12,5))
ax2.bar(agm['age'], agm['Evaluation'], color='green')
ax2.set_xlabel('Age')
ax2.set_ylabel('Average Evaluation')
ax2.set_title('Average Evaluation by Age')

plt.show()

# %%
demo.keys()
# Out:
# Index(['pew_religimp', 'pew_churatd', 'sex', 'educ', 'nonwhite', 'age',
#        'faminc_new', 'pid3', 'ideo5', 'QueerPhobia', 'ImmiPhobia',
#        'InterGBiasParty', 'InterGBiasCand', 'InterGBiasSup', 'LibMediaUse',
#        'ConMediaUse', 'Real_Threat', 'Symb_Threat', 'Evaluation', 'teamweight',
#        'caseid'],
#       dtype='object')

# %%
fig3, ax3 = plt.subplots(figsize = (10,7))
ax3.scatter(x = demo['ImmiPhobia'], y = demo['ConMediaUse'],alpha=0.5)
ax3.set_xlabel('ConMediaUse')
ax3.set_ylabel('ImmiPhobia')
ax3.set_title('ConMediaUse vs. ImmiPhobia')
plt.grid(True)
plt.show()

# %%
demo['ImmiPhobia']
# Out:
# 0      1.0
# 1      1.0
# 2      3.5
# 3      1.0
# 4      1.0
#       ...
# 654    2.0
# 655    1.0
# 656    1.0
# 657    2.5
# 658    2.5
# Name: ImmiPhobia, Length: 659, dtype: float64
